# %%
import pandas as pd
import numpy as np
import random
import io

# %%
econdata = pd.read_csv("economia-y-turismo.csv")

# %%
econdata.head()
# Out:
#    id                  geo_point_2d  \
# 0   0   19.424781053,-99.1327537959
# 1   1  19.4346139576,-99.1413808393
# 2   2  19.4340695945,-99.1306348409
# 3   3      19.42489472,-99.12073393
# 4   4      19.42358238,-99.12451093
#
#                                            geo_shape   clave_cat  \
# 0  {"type": "Polygon", "coordinates": [[[-99.1332...  307_130_11
# 1  {"type": "MultiPoint", "coordinates": [[-99.14...  002_008_01
# 2  {"type": "MultiPoint", "coordinates": [[-99.13...  006_002_12
# 3  {"type": "MultiPoint", "coordinates": [[-99.12...  323_102_06
# 4  {"type": "MultiPoint", "coordinates": [[-99.12...  323_115_12
#
#             delegacion perimetro     tipo  \
# 0           Cuauhtémoc         B  Mercado
# 1            Cuautémoc         A    Museo
# 2            Cuautémoc         A    Museo
# 3  Venustiano Carranza         B    Hotel
# 4  Venustiano Carranza         B    Hotel
#
#                                               nom_id
# 0                                        Pino Suárez
# 1  Museo Nacional de Arquitectura Palacio de Bell...
# 2                                       Santa Teresa
# 3                                           Balbuena
# 4                                               real

# %% [markdown]
# ## Funciones de muestre
#
# ### Muestreo aleatorio simple

# %%
aleatorio_8 = econdata.sample(n=4)
aleatorio_8
# Out:
#       id                  geo_point_2d  \
# 167  167  19.4387807061,-99.1398360896
# 121  121  19.4303083246,-99.1405735286
# 71    71  19.4243073771,-99.1314527126
# 106  106  19.4260404694,-99.1546283991
#
#                                              geo_shape   clave_cat  \
# 167  {"type": "MultiPoint", "coordinates": [[-99.13...  004_072_07
# 121  {"type": "MultiPoint", "coordinates": [[-99.14...  001_043_15
# 71   {"type": "MultiPoint", "coordinates": [[-99.13...  307_129_17
# 106  {"type": "Polygon", "coordinates": [[[-99.1550...  011_245_01
#
#      delegacion perimetro     tipo             nom_id
# 167   Cuautémoc         A    Hotel  Diligencias, S.A.
# 121   Cuautémoc         A    Hotel        El Salvador
# 71    Cuautémoc         B    Hotel             Recreo
# 106  Cuauhtémoc         B  Mercado             Juárez

# %%
proporcion_25 = econdata.sample(frac = 0.25)
proporcion_25
# Out:
#       id                  geo_point_2d  \
# 192  192  19.4313325389,-99.1497520491
# 66    66  19.4331350004,-99.1382989213
# 91    91      19.42981826,-99.14607091
# 164  164  19.4388741511,-99.1413308257
# 4      4      19.42358238,-99.12451093
# 43    43  19.4343713052,-99.1291939496
# 100  100  19.4337759404,-99.1378211234
# 18    18  19.4331161255,-99.1309438719
# 193  193  19.4269448376,-99.1305051483
# 203  203  19.4298553268,-99.1327269808
# 63    63  19.4339116282,-99.1468371035
# 159  159  19.4337392469,-99.1311991819
# 32    32  19.4369607249,-99.1354098031
# 120  120   19.438089976,-99.1374885065
# 190  190      19.43311885,-99.14512643
# 41    41      19.43204901,-99.13440135
# 188  188  19.4281241134,-99.1460742157
# 183  183      19.43807011,-99.13611488
# 104  104      19.43397933,-99.13044075
# 42    42  19.4368553413,-99.1196435872
# 65    65   19.425466805,-99.1380880561
# 37    37   19.4271233834,-99.125111772
# 160  160    19.43610539,-99.1394124008
# 140  140  19.4374331486,-99.1457705763
# 181  181  19.4451852396,-99.1478597989
# 93    93  19.4352977961,-99.1412872705
# 56    56  19.4452114301,-99.1425281852
# 97    97  19.4440005647,-99.1372278043
# 50    50   19.427412415,-99.1425547699
# 171  171  19.4263416792,-99.1296771488
# 133  133  19.4388860834,-99.1250947991
# 96    96  19.4236741422,-99.1558164031
# 124  124  19.4297560476,-99.1253498219
# 126  126      19.42774805,-99.12796532
# 178  178  19.4457531395,-99.1485982115
# 155  155  19.4416371812,-99.1477800117
# 102  102   19.4394492343,-99.137176496
# 211  211   19.4325804122,-99.146356862
# 223  223  19.4285106481,-99.1367967407
# 68    68  19.4273142523,-99.1255788881
# 110  110  19.4356877258,-99.1387888649
# 153  153  19.4241764183,-99.1254198454
# 207  207  19.4344738803,-99.1305689118
# 99    99  19.4438918423,-99.1402516182
# 224  224  19.4238397797,-99.1371356587
# 215  215  19.4383767258,-99.1331865203
# 38    38  19.4439555857,-99.1345196425
# 167  167  19.4387807061,-99.1398360896
# 24    24   19.4285279152,-99.147008562
# 47    47     19.439101835,-99.13175662
# 57    57  19.4303913751,-99.1465372648
# 3      3      19.42489472,-99.12073393
# 145  145  19.4340221684,-99.1358187396
# 157  157  19.4272935771,-99.1227492994
# 143  143   19.4327710138,-99.142002608
# 129  129                           NaN
# 187  187  19.4252269549,-99.1252325326
# 219  219  19.4234096295,-99.1438351156
#
#                                              geo_shape   clave_cat  \
# 192  {"type": "MultiPoint", "coordinates": [[-99.14...  002_052_04
# 66   {"type": "MultiPoint", "coordinates": [[-99.13...  001_021_14
# 91   {"type": "MultiPoint", "coordinates": [[-99.14...  002_059_01
# 164  {"type": "MultiPoint", "coordinates": [[-99.14...  003_113_03
# 4    {"type": "MultiPoint", "coordinates": [[-99.12...  323_115_12
# 43   {"type": "MultiPoint", "coordinates": [[-99.12...  006_003_19
# 100  {"type": "MultiPoint", "coordinates": [[-99.13...  001_014_06
# 18   {"type": "MultiPoint", "coordinates": [[-99.13...  006_021_01
# 193  {"type": "MultiPoint", "coordinates": [[-99.13...  006_091_20
# 203  {"type": "MultiPoint", "coordinates": [[-99.13...  001_039_28
# 63   {"type": "MultiPoint", "coordinates": [[-99.14...  002_015_07
# 159  {"type": "MultiPoint", "coordinates": [[-99.13...  006_001_06
# 32   {"type": "MultiPoint", "coordinates": [[-99.13...  004_101_20
# 120  {"type": "MultiPoint", "coordinates": [[-99.13...  004_086_24
# 190  {"type": "MultiPoint", "coordinates": [[-99.14...  002_019_02
# 41   {"type": "MultiPoint", "coordinates": [[-99.13...  001_024_09
# 188  {"type": "MultiPoint", "coordinates": [[-99.14...  002_067_08
# 183  {"type": "MultiPoint", "coordinates": [[-99.13...  004_075_07
# 104  {"type": "MultiPoint", "coordinates": [[-99.13...  006_002_12
# 42   {"type": "MultiPoint", "coordinates": [[-99.11...  018_337_01
# 65   {"type": "MultiPoint", "coordinates": [[-99.13...  001_073_20
# 37   {"type": "Polygon", "coordinates": [[[-99.1251...  323_065_01
# 160  {"type": "MultiPoint", "coordinates": [[-99.13...  004_098_01
# 140  {"type": "MultiPoint", "coordinates": [[-99.14...  003_092_06
# 181  {"type": "MultiPoint", "coordinates": [[-99.14...  012_103_01
# 93   {"type": "MultiPoint", "coordinates": [[-99.14...  002_007_01
# 56   {"type": "MultiPoint", "coordinates": [[-99.14...  003_043_01
# 97   {"type": "MultiPoint", "coordinates": [[-99.13...  004_038_04
# 50   {"type": "Polygon", "coordinates": [[[-99.1427...  002_064_05
# 171  {"type": "MultiPoint", "coordinates": [[-99.12...  006_092_06
# 133  {"type": "MultiPoint", "coordinates": [[-99.12...  005_099_14
# 96   {"type": "MultiPoint", "coordinates": [[-99.15...  010_015_08
# 124  {"type": "MultiPoint", "coordinates": [[-99.12...  006_052_01
# 126  {"type": "MultiPoint", "coordinates": [[-99.12...  006_078_04
# 178  {"type": "MultiPoint", "coordinates": [[-99.14...  012_069_11
# 155  {"type": "MultiPoint", "coordinates": [[-99.14...  003_078_18
# 102  {"type": "MultiPoint", "coordinates": [[-99.13...  004_076_16
# 211  {"type": "MultiPoint", "coordinates": [[-99.14...  002_032_01
# 223  {"type": "MultiPoint", "coordinates": [[-99.13...  001_055_10
# 68   {"type": "MultiPoint", "coordinates": [[-99.12...  006_082_02
# 110  {"type": "MultiPoint", "coordinates": [[-99.13...  001_003_11
# 153  {"type": "MultiPoint", "coordinates": [[-99.12...  323_133_29
# 207  {"type": "MultiPoint", "coordinates": [[-99.13...  006_002_13
# 99   {"type": "MultiPoint", "coordinates": [[-99.14...  003_052_18
# 224  {"type": "MultiPoint", "coordinates": [[-99.13...  001_109_11
# 215  {"type": "MultiPoint", "coordinates": [[-99.13...  004_082_16
# 38   {"type": "Polygon", "coordinates": [[[-99.1351...  004_106_01
# 167  {"type": "MultiPoint", "coordinates": [[-99.13...  004_072_07
# 24   {"type": "MultiPoint", "coordinates": [[-99.14...  002_067_19
# 47   {"type": "MultiPoint", "coordinates": [[-99.13...  004_081_31
# 57   {"type": "MultiPoint", "coordinates": [[-99.14...  002_048_10
# 3    {"type": "MultiPoint", "coordinates": [[-99.12...  323_102_06
# 145  {"type": "MultiPoint", "coordinates": [[-99.13...  001_012_11
# 157  {"type": "Polygon", "coordinates": [[[-99.1230...  323_063_08
# 143  {"type": "MultiPoint", "coordinates": [[-99.14...  002_027_10
# 129                                                NaN  005_125_01
# 187  {"type": "MultiPoint", "coordinates": [[-99.12...  323_118_36
# 219  {"type": "MultiPoint", "coordinates": [[-99.14...  002_118_03
#
#               delegacion perimetro     tipo  \
# 192            Cuautémoc         B    Hotel
# 66             Cuautémoc         A    Hotel
# 91             Cuautémoc         B    Hotel
# 164            Cuautémoc         B    Hotel
# 4    Venustiano Carranza         B    Hotel
# 43             Cuautémoc         A    Hotel
# 100            Cuautémoc         A    Hotel
# 18             Cuautémoc         A    Museo
# 193            Cuautémoc         A    Hotel
# 203            Cuautémoc         A    Hotel
# 63             Cuautémoc         B    Hotel
# 159            Cuautémoc         A    Museo
# 32             Cuautémoc         A    Hotel
# 120            Cuautémoc         A    Hotel
# 190            Cuautémoc         B    Hotel
# 41             Cuautémoc         A    Hotel
# 188            Cuautémoc         B    Hotel
# 183            Cuautémoc         A    Hotel
# 104            Cuautémoc         A    Hotel
# 42   Venustiano Carranza         B    Hotel
# 65             Cuautémoc         B    Hotel
# 37   Venustiano Carranza         B  Mercado
# 160            Cuautémoc         A    Museo
# 140            Cuautémoc         A    Hotel
# 181            Cuautémoc         B    Hotel
# 93             Cuautémoc         A    Museo
# 56             Cuautémoc         B    Hotel
# 97             Cuautémoc         B    Museo
# 50            Cuauhtémoc         B  Mercado
# 171            Cuautémoc         A    Hotel
# 133            Cuautémoc         B    Hotel
# 96             Cuautémoc         B    Hotel
# 124            Cuautémoc         A    Hotel
# 126            Cuautémoc         A    Hotel
# 178            Cuautémoc         B    Hotel
# 155            Cuautémoc         B    Hotel
# 102            Cuautémoc         A    Hotel
# 211            Cuautémoc         B    Hotel
# 223            Cuautémoc         A    Hotel
# 68             Cuautémoc         A    Hotel
# 110            Cuautémoc         A    Museo
# 153  Venustiano Carranza         B    Hotel
# 207            Cuautémoc         A    Museo
# 99             Cuautémoc         B    Hotel
# 224            Cuautémoc         B    Hotel
# 215            Cuautémoc         A    Hotel
# 38            Cuauhtémoc         B  Mercado
# 167            Cuautémoc         A    Hotel
# 24             Cuautémoc         B    Hotel
# 47             Cuautémoc         A    Hotel
# 57             Cuautémoc         B    Hotel
# 3    Venustiano Carranza         B    Hotel
# 145            Cuautémoc         A    Hotel
# 157  Venustiano Carranza         B  Mercado
# 143            Cuautémoc         B    Hotel
# 129           Cuauhtémoc         A  Mercado
# 187  Venustiano Carranza         B    Hotel
# 219            Cuautémoc         B    Hotel
#
#                                                 nom_id
# 192                                             Panuco
# 66                                             Coliseo
# 91                                             Pugibet
# 164                                       Dos Naciones
# 4                                                 real
# 43                                            Valencia
# 100                             Ritz Ciudada de México
# 18                      Museo Nacional de las Culturas
# 193                                             Regina
# 203                                              Roble
# 63                                              Calvin
# 159  Arte de la Secretaria de Hacienda y Credito Pu...
# 32                                        Habana, S.A.
# 120                                Atlanta, S. DE R.L.
# 190                                           Metropol
# 41                   Gran Hotel de la Ciudad de México
# 188                                           Manolo 1
# 183                                     Antillas, S.A.
# 104                                            Palacio
# 42                                      HOTEL RRO MI1O
# 65                                                 Mar
# 37                                            Dulceria
# 160                             Museo Nacional de Arte
# 140                                    Boutique Cortes
# 181                                               Yale
# 93                             Palacio de Bellas Artes
# 56                                             Morelia
# 97                                   Galeria El Trébol
# 50                                      San Juan No.78
# 171                                         Las Cruces
# 133                                            Venecia
# 96                                              Puebla
# 124                                           Universo
# 126                                         San Marcos
# 178                                              Norte
# 155                                             Trébol
# 102                                             Sonora
# 211                                            Fleming
# 223                                               Niza
# 68                                             Anpudia
# 110                 Museo interactivo de economía Mide
# 153                                              Navio
# 207                            Autonomía Universitaria
# 99                                            Drigales
# 224                               Costa Azul, SA DE CV
# 215                        La Fontelina , S.A. DE C.V.
# 38                            La Lagunilla Comestibles
# 167                                  Diligencias, S.A.
# 24                                              Fornos
# 47                                             Bolivia
# 57                                               Conde
# 3                                             Balbuena
# 145                                              Rioja
# 157                                     Merced Comidas
# 143                                             Toledo
# 129                                           Abelardo
# 187                                             Necaxa
# 219                                     Prado Floresta

# %% [markdown]
# ## Muestreo sistematico (indicando una condicion)

# %%
def systematic_sampling(econdata, step):
    indexes = np.arange(0, len(econdata), step=step)
    systematic_sample = econdata.iloc[indexes]
    return systematic_sample


systematic_sample = systematic_sampling(econdata, 3)
systematic_sample
# Out:
#       id                  geo_point_2d  \
# 0      0   19.424781053,-99.1327537959
# 3      3      19.42489472,-99.12073393
# 6      6      19.43553422,-99.12324801
# 9      9  19.4407152937,-99.1498060057
# 12    12      19.43990186,-99.14813347
# ..   ...                           ...
# 216  216  19.4247697438,-99.1249707246
# 219  219  19.4234096295,-99.1438351156
# 222  222   19.4397905042,-99.134628735
# 225  225      19.43094655,-99.12455418
# 228  228  19.4406567734,-99.1394531646
#
#                                              geo_shape   clave_cat  \
# 0    {"type": "Polygon", "coordinates": [[[-99.1332...  307_130_11
# 3    {"type": "MultiPoint", "coordinates": [[-99.12...  323_102_06
# 6    {"type": "MultiPoint", "coordinates": [[-99.12...  318_116_11
# 9    {"type": "MultiPoint", "coordinates": [[-99.14...  012_146_22
# 12   {"type": "MultiPoint", "coordinates": [[-99.14...  003_079_16
# ..                                                 ...         ...
# 216  {"type": "Polygon", "coordinates": [[[-99.1250...  323_118_37
# 219  {"type": "MultiPoint", "coordinates": [[-99.14...  002_118_03
# 222  {"type": "MultiPoint", "coordinates": [[-99.13...  004_063_10
# 225  {"type": "MultiPoint", "coordinates": [[-99.12...  323_027_04
# 228  {"type": "MultiPoint", "coordinates": [[-99.13...  004_069_01
#
#               delegacion perimetro     tipo                  nom_id
# 0             Cuauhtémoc         B  Mercado             Pino Suárez
# 3    Venustiano Carranza         B    Hotel                Balbuena
# 6    Venustiano Carranza         B    Hotel    San Antonio Tomatlan
# 9              Cuautémoc         B    Hotel                 Detroit
# 12             Cuautémoc         B    Hotel                  La Paz
# ..                   ...       ...      ...                     ...
# 216  Venustiano Carranza         B  Mercado  Lamininas de La Merced
# 219            Cuautémoc         B    Hotel          Prado Floresta
# 222            Cuautémoc         A    Hotel                  Ladero
# 225  Venustiano Carranza         B    Hotel           Gran Veracruz
# 228            Cuautémoc         B    Museo        Tequila y Mescal
#
# [77 rows x 8 columns]

# %% [markdown]
# ## Muestreo estratrificado

# %%
econdata['estratificado'] = econdata['delegacion'] + "," + econdata["tipo"]
(econdata['estratificado'].value_counts()/len(econdata)).sort_values(ascending=False)
# Out:
# Cuautémoc,Hotel                0.643478
# Cuautémoc,Museo                0.156522
# Venustiano Carranza,Hotel      0.078261
# Cuauhtémoc,Mercado             0.073913
# Venustiano Carranza,Mercado    0.047826
# Name: estratificado, dtype: float64

# %% [markdown]
# Nuestros datos dicen que la proporcion es:
#
# 1) Hoteles en Cuauhtémoc 0.5
#
# 2) Museos en Cuauhtémoc 0.2
#
# 3) Hoteles en Venustiana Carranza 0.1
#
# 4) Mercados en Cuauhtémoc 0.1
#
# 5) Mercados en Venusiano Carranza 0.1

# %%
def data_estratificado(econdata, nombres_columnas_estrat, valores_estrat, prop_estrat, random_state=None):
    df_estrat = pd.DataFrame(columns = econdata.columns)
    
    pos = -1 
    for i in range (len(valores_estrat)):
        pos+=1
        if pos == len(valores_estrat) -1:
            rati_len = len(econdata) - len(df_estrat)
        else:
            ratio_len = int(len(econdata) * prop_estrat[i])
            
        df_filtrado = econdata[econdata[nombres_columnas_estrat] == valores_estrat[i]]    
        df_temp = df_filtrado.sample(replace=True, n = ratio_len, random_state=random_state)
        
        df_estrat = pd.concat([df_estrat, df_temp])
        return df_estrat

# %%
valores_estrat = ['Cuautémoc,Hotel', 'Cuautémoc,Museo', 'Venustiano Carranza,Hotel', 'Cuauhtémoc,Mercado', 'Venustiano Carranza,Mercado']
prop_estrat = [0.5, 0.2, 0.1, 0.1, 0.1]

               
df_estrat = data_estratificado(econdata, 'estratificado', valores_estrat, prop_estrat, random_state=42)            
df_estrat
# Out:
#       id                  geo_point_2d  \
# 164  164  19.4388741511,-99.1413308257
# 142  142  19.4263681354,-99.1327278126
# 27    27  19.4348360773,-99.1463945583
# 168  168   19.4349726565,-99.147766133
# 113  113      19.43374405,-99.13550135
# ..   ...                           ...
# 66    66  19.4331350004,-99.1382989213
# 193  193  19.4269448376,-99.1305051483
# 99    99  19.4438918423,-99.1402516182
# 145  145  19.4340221684,-99.1358187396
# 83    83  19.4342251093,-99.1449434443
#
#                                              geo_shape   clave_cat delegacion  \
# 164  {"type": "MultiPoint", "coordinates": [[-99.14...  003_113_03  Cuautémoc
# 142  {"type": "MultiPoint", "coordinates": [[-99.13...  006_127_14  Cuautémoc
# 27   {"type": "MultiPoint", "coordinates": [[-99.14...  002_016_01  Cuautémoc
# 168  {"type": "MultiPoint", "coordinates": [[-99.14...  002_014_23  Cuautémoc
# 113  {"type": "MultiPoint", "coordinates": [[-99.13...  001_012_13  Cuautémoc
# ..                                                 ...         ...        ...
# 66   {"type": "MultiPoint", "coordinates": [[-99.13...  001_021_14  Cuautémoc
# 193  {"type": "MultiPoint", "coordinates": [[-99.13...  006_091_20  Cuautémoc
# 99   {"type": "MultiPoint", "coordinates": [[-99.14...  003_052_18  Cuautémoc
# 145  {"type": "MultiPoint", "coordinates": [[-99.13...  001_012_11  Cuautémoc
# 83   {"type": "MultiPoint", "coordinates": [[-99.14...  002_018_03  Cuautémoc
#
#     perimetro   tipo                   nom_id    estratificado
# 164         B  Hotel             Dos Naciones  Cuautémoc,Hotel
# 142         A  Hotel                    Ambar  Cuautémoc,Hotel
# 27          B  Hotel  Hilton Centro Histórico  Cuautémoc,Hotel
# 168         B  Hotel              One Alameda  Cuautémoc,Hotel
# 113         A  Hotel              San Antonio  Cuautémoc,Hotel
# ..        ...    ...                      ...              ...
# 66          A  Hotel                  Coliseo  Cuautémoc,Hotel
# 193         A  Hotel                   Regina  Cuautémoc,Hotel
# 99          B  Hotel                 Drigales  Cuautémoc,Hotel
# 145         A  Hotel                    Rioja  Cuautémoc,Hotel
# 83          B  Hotel            San Francisco  Cuautémoc,Hotel
#
# [115 rows x 9 columns]
