# %%
import pandas as pd
import numpy as np
import random
import io

# %% [markdown]
# # Introduccion

# %%
econdata = pd.read_csv("economia-y-turismo.csv")

# %%
econdata.head()
# Out:
#    id                  geo_point_2d  \
# 0   0   19.424781053,-99.1327537959
# 1   1  19.4346139576,-99.1413808393
# 2   2  19.4340695945,-99.1306348409
# 3   3      19.42489472,-99.12073393
# 4   4      19.42358238,-99.12451093
#
#                                            geo_shape   clave_cat  \
# 0  {"type": "Polygon", "coordinates": [[[-99.1332...  307_130_11
# 1  {"type": "MultiPoint", "coordinates": [[-99.14...  002_008_01
# 2  {"type": "MultiPoint", "coordinates": [[-99.13...  006_002_12
# 3  {"type": "MultiPoint", "coordinates": [[-99.12...  323_102_06
# 4  {"type": "MultiPoint", "coordinates": [[-99.12...  323_115_12
#
#             delegacion perimetro     tipo  \
# 0           Cuauhtémoc         B  Mercado
# 1            Cuautémoc         A    Museo
# 2            Cuautémoc         A    Museo
# 3  Venustiano Carranza         B    Hotel
# 4  Venustiano Carranza         B    Hotel
#
#                                               nom_id
# ...

# %% [markdown]
# ## Funciones de muestre
#
# ### Muestreo aleatorio simple

# %%
aleatorio_8 = econdata.sample(n=4)
aleatorio_8
# Out:
#     id                  geo_point_2d  \
# 73  73  19.4218384283,-99.1267852296
# 83  83  19.4342251093,-99.1449434443
# 33  33  19.4341938751,-99.1352210651
# 11  11  19.4219963186,-99.1437414652
#
#                                             geo_shape   clave_cat delegacion  \
# 73  {"type": "MultiPoint", "coordinates": [[-99.12...  007_005_07  Cuautémoc
# 83  {"type": "MultiPoint", "coordinates": [[-99.14...  002_018_03  Cuautémoc
# 33  {"type": "MultiPoint", "coordinates": [[-99.13...  001_007_04  Cuautémoc
# 11  {"type": "MultiPoint", "coordinates": [[-99.14...  002_103_18  Cuautémoc
#
#    perimetro   tipo         nom_id
# 73         B  Hotel           Jaen
# 83         B  Hotel  San Francisco
# 33         A  Hotel    Washingtonw
# 11         B  Hotel           Faro

# %%
proporcion_25 = econdata.sample(frac = 0.25)
proporcion_25
# Out:
#       id                  geo_point_2d  \
# 156  156  19.4255480371,-99.1249308096
# 58    58  19.4244380424,-99.1306732022
# 63    63  19.4339116282,-99.1468371035
# 105  105  19.4298675871,-99.1370239721
# 187  187  19.4252269549,-99.1252325326
# 148  148  19.4388349207,-99.1502578596
# 4      4      19.42358238,-99.12451093
# 170  170      19.43162145,-99.13535842
# 226  226  19.4416748524,-99.1365878489
# 140  140  19.4374331486,-99.1457705763
# 171  171  19.4263416792,-99.1296771488
# 175  175  19.4291934671,-99.1323328561
# 38    38  19.4439555857,-99.1345196425
# 132  132  19.4248733452,-99.1202942813
# 126  126      19.42774805,-99.12796532
# 194  194  19.4288786806,-99.1456731565
# 81    81      19.42262452,-99.15107339
# 87    87  19.4397239469,-99.1461558557
# 181  181  19.4451852396,-99.1478597989
# 110  110  19.4356877258,-99.1387888649
# 111  111  19.4430614318,-99.1353793874
# 225  225      19.43094655,-99.12455418
# 26    26  19.4262321913,-99.1238893146
# ...

# %% [markdown]
# ## Muestreo sistematico (indicando una condicion)

# %%
def systematic_sampling(econdata, step):
    indexes = np.arange(0, len(econdata), step=step)
    systematic_sample = econdata.iloc[indexes]
    return systematic_sample


systematic_sample = systematic_sampling(econdata, 3)
systematic_sample
# Out:
#       id                  geo_point_2d  \
# 0      0   19.424781053,-99.1327537959
# 3      3      19.42489472,-99.12073393
# 6      6      19.43553422,-99.12324801
# 9      9  19.4407152937,-99.1498060057
# 12    12      19.43990186,-99.14813347
# ..   ...                           ...
# 216  216  19.4247697438,-99.1249707246
# 219  219  19.4234096295,-99.1438351156
# 222  222   19.4397905042,-99.134628735
# 225  225      19.43094655,-99.12455418
# 228  228  19.4406567734,-99.1394531646
#
#                                              geo_shape   clave_cat  \
# 0    {"type": "Polygon", "coordinates": [[[-99.1332...  307_130_11
# 3    {"type": "MultiPoint", "coordinates": [[-99.12...  323_102_06
# 6    {"type": "MultiPoint", "coordinates": [[-99.12...  318_116_11
# 9    {"type": "MultiPoint", "coordinates": [[-99.14...  012_146_22
# 12   {"type": "MultiPoint", "coordinates": [[-99.14...  003_079_16
# ..                                                 ...         ...
# ...

# %% [markdown]
# ## Muestreo estratrificado

# %%
econdata['estratificado'] = econdata['delegacion'] + "," + econdata["tipo"]
(econdata['estratificado'].value_counts()/len(econdata)).sort_values(ascending=False)
# Out:
# Cuautémoc,Hotel                0.643478
# Cuautémoc,Museo                0.156522
# Venustiano Carranza,Hotel      0.078261
# Cuauhtémoc,Mercado             0.073913
# Venustiano Carranza,Mercado    0.047826
# Name: estratificado, dtype: float64

# %% [markdown]
# Nuestros datos dicen que la proporcion es:
#
# 1) Hoteles en Cuauhtémoc 0.5
#
# 2) Museos en Cuauhtémoc 0.2
#
# 3) Hoteles en Venustiana Carranza 0.1
#
# 4) Mercados en Cuauhtémoc 0.1
#
# 5) Mercados en Venusiano Carranza 0.1

# %%
def data_estratificado(econdata, nombres_columnas_estrat, valores_estrat, prop_estrat, random_state=None):
    df_estrat = pd.DataFrame(columns = econdata.columns)
    
    pos = -1 
    for i in range (len(valores_estrat)):
        pos+=1
        if pos == len(valores_estrat) -1:
            rati_len = len(econdata) - len(df_estrat)
        else:
            ratio_len = int(len(econdata) * prop_estrat[i])
            
        df_filtrado = econdata[econdata[nombres_columnas_estrat] == valores_estrat[i]]    
        df_temp = df_filtrado.sample(replace=True, n = ratio_len, random_state=random_state)
        
        df_estrat = pd.concat([df_estrat, df_temp])
        return df_estrat

# %%
valores_estrat = ['Cuautémoc,Hotel', 'Cuautémoc,Museo', 'Venustiano Carranza,Hotel', 'Cuauhtémoc,Mercado', 'Venustiano Carranza,Mercado']
prop_estrat = [0.5, 0.2, 0.1, 0.1, 0.1]

               
df_estrat = data_estratificado(econdata, 'estratificado', valores_estrat, prop_estrat, random_state=42)            
df_estrat
# Out:
#       id                  geo_point_2d  \
# 164  164  19.4388741511,-99.1413308257
# 142  142  19.4263681354,-99.1327278126
# 27    27  19.4348360773,-99.1463945583
# 168  168   19.4349726565,-99.147766133
# 113  113      19.43374405,-99.13550135
# ..   ...                           ...
# 66    66  19.4331350004,-99.1382989213
# 193  193  19.4269448376,-99.1305051483
# 99    99  19.4438918423,-99.1402516182
# 145  145  19.4340221684,-99.1358187396
# 83    83  19.4342251093,-99.1449434443
#
#                                              geo_shape   clave_cat delegacion  \
# 164  {"type": "MultiPoint", "coordinates": [[-99.14...  003_113_03  Cuautémoc
# 142  {"type": "MultiPoint", "coordinates": [[-99.13...  006_127_14  Cuautémoc
# 27   {"type": "MultiPoint", "coordinates": [[-99.14...  002_016_01  Cuautémoc
# 168  {"type": "MultiPoint", "coordinates": [[-99.14...  002_014_23  Cuautémoc
# 113  {"type": "MultiPoint", "coordinates": [[-99.13...  001_012_13  Cuautémoc
# ...

# %% [markdown]
# ## Tipos de pruebas de hipotesis

# %%
import pandas as pd
import random
import numpy as np
import seaborn as sns
import scipy.stats as st
from scipy.stats import f_oneway
from scipy.stats import ttest_ind

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as st
from scipy.stats import f_oneway
from scipy.stats import ttest_ind

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
names = ['sepal-length"', 'sepal-width', 'petal-length', 'petal-width', 'class']
iris = pd.read_csv(url, names=names)

iris.head()
# Out:
#    sepal-length"  sepal-width  petal-length  petal-width        class
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Tipos de pruebas

# %% [markdown]
# ### T-Student

# %%
se_length = iris.std()['sepal-length"']/np.sqrt(10)
se_width = iris.std()['sepal-width']/np.sqrt(10)
# Out:
# /tmp/ipykernel_201/967270464.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   se_length = iris.std()['sepal-length"']/np.sqrt(10)
# /tmp/ipykernel_201/967270464.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   se_width = iris.std()['sepal-width']/np.sqrt(10)

# %%
sed=np.sqrt((se_length**2) + (se_width**2))

# %%
t_stat=(iris.mean()['sepal-length"'] - iris.mean()['sepal-width'])/sed
t_stat
# Out:
# /tmp/ipykernel_201/99762379.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   t_stat=(iris.mean()['sepal-length"'] - iris.mean()['sepal-width'])/sed
# 9.436693738890318

# %%
p = ttest_ind(iris['sepal-length"'], iris['sepal-width'])
p
# Out:
# Ttest_indResult(statistic=36.548157693982006, pvalue=3.987838114848222e-112)

# %% [markdown]
# ### b) Correlación y coeficiente de Pearson

# %%
# Estudiamos la correlación entre length y width
iris['sepal-length"'].corr(iris['sepal-width'])
# Out:
# -0.10936924995064937

# %%
# A continuación, estudiamos la correlación de Pearson entre ambas variables
st.pearsonr(iris['sepal-length"'], iris['sepal-width'])
# Out:
# (-0.10936924995064938, 0.1827652152713699)

# %% [markdown]
# ### c) Análisis de la varianza (ANOVA)

# %%
f_oneway(iris['sepal-length"'], iris['sepal-width'])
# Out:
# F_onewayResult(statistic=1335.7678308241748, pvalue=3.9878381148486907e-112)

# %% [markdown]
# **Con todas las  pruebas realizadas se rechaza la hipotesis**

# %% [markdown]
# # Bootstraping
#
# ### Obtener una muestra aleatoria y luego obtener muestras de las muestras se supone que se llega a una distribucion normal
#
# <img align="left" src = https://builtin.com/sites/www.builtin.com/files/styles/ckeditor_optimize/public/inline-images/1_bootstrapping-statistics.jpeg width=400 style="padding: 10px">

# %%
data = np.random.normal(loc =34, size = 100000)
data
# Out:
# array([34.44717711, 34.54288842, 32.93921099, ..., 33.3466156 ,
#        33.54735192, 33.87576966])

# %%
data.mean()
# Out:
# 33.99906955755203

# %% [markdown]
# **Iniciamos bootstraqping para calcular el promedio de las edades**

# %%
promedio = []
for i in range(40):
    muestra = random.sample(data.tolist(), 5)
    prom = np.mean(muestra)
    promedio.append(prom)

# %%
np.mean(promedio)
# Out:
# 33.92434033389685

# %% [markdown]
# # Valicion cruzada

# %% [markdown]
# Validación Cruzada
# Es la técnica utilizada para evaluar los resultados de un análisis estadístico y garantizar que son independientes de la partición entre datos de entrenamiento y prueba.
#
# Procedimiento:
#
# Hay que dividir los datos de forma aleatoria en K grupos de tamaño similar.
# Usar K-1 grupos para entrenar el modelo
# Tomar uno de estos grupos para validar el modelo
# Repetir K veces usando grupos distintos en cada iteración

# %%
df = pd.read_csv("data.csv") # datos de cancer
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
X = df.iloc[:, 2:]
Y = df.iloc[:, 1]

# %%
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
Y.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
print(X_train.isnull().any().any())
# Out:
# False

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 4)
# random ststae es el nivel de presision

X_train = X_train.dropna(axis=1)
X_test = X_test.dropna(axis=1)

modelo = DecisionTreeClassifier()
modelo.fit(X_train, Y_train)
resultado = modelo.score(X_test, Y_test)

# %%
print(resultado)
# Out:
# 0.9005847953216374

# %% [markdown]
# ** Hacemos la validacion cruzada **

# %%
from sklearn.model_selection import KFold

# %%
modelo = DecisionTreeClassifier()
kfold_validation = KFold(10) #10 Folds/muestras

# %%
from sklearn.model_selection import cross_val_score

# %%
X = X.dropna(axis=1)

# %%
resultados = cross_val_score(modelo, X, Y, cv = kfold_validation)
print (resultados)
resultados.mean()
# Out:
# [0.92982456 0.9122807  0.87719298 0.94736842 0.89473684 0.96491228
#  0.9122807  0.92982456 0.94736842 0.96428571]
# 0.9280075187969924

# %% [markdown]
# ### el promedio de las muestras es de 0.92 que indica que las muestras son correctas

# %%
4 != 10
# Out:
# True
